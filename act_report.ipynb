# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# #### Research question: What dog stage got the most favorite counts?

# %% [markdown]
# ![fav%20count%20by%20stage.png](attachment:fav%20count%20by%20stage.png)

# %% [markdown]
# > This image represents the favorite count per dog stage. It highlights that the puppo dog stage is the most favorited stage out of all the stages.

# %% [markdown]
# #### Research Question: What dog stage got the most retweet counts?

# %% [markdown]
# ![retweet%20count%20by%20stage.png](attachment:retweet%20count%20by%20stage.png)

# %% [markdown]
# > This image represents the retweet count per dog stage. It highlights that the puppo and doggo dog stage closely contest the most retweets among the rating population

# %% [markdown]
# #### Research Question: What are the top 5 favorite tweets?

# %% [markdown]
# ![top%20fav%20tweets.jpg](attachment:top%20fav%20tweets.jpg)

# %% [markdown]
# > This table shows the tweets with the highest favorite count

# %% [markdown]
# #### Research Question: What are the top 5 retweeted tweets?

# %% [markdown]
# ![top%20retweeted%20tweets.jpg](attachment:top%20retweeted%20tweets.jpg)

# %% [markdown]
# > This table shows the tweets with the highest retweet count

# %% [markdown]
# #### Research Question: What is the common dog stage?

# %% [markdown]
# ![tweets%20per%20stage.jpg](attachment:tweets%20per%20stage.jpg)

# %% [markdown]
# > This table shows the numnber of tweets per stage, revealing that the pupper stage obtained the most tweets

# %% [markdown]
# #### Conclusion
#
# > From the insights gathered we see that the `Pupper` stage with the most tweets didn't garner the most retweets or favorites from the population. `Puppo` which carried one of the lowest tweets garnered the highest number of favorites anf retweets while among individual tweets the tweet that had the highest favorite count and retweet count was of the stage of `Doggo`
